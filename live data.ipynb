# %%
import numpy as np
import pandas as pd

import yfinance as yf

# %%
import plotly.graph_objs as go

# %%
data = yf.download(tickers='UBER',period='5d',interval='1m')
#interval requied 1 min
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                                 Open       High        Low      Close  \
# Datetime
# 2024-05-24 09:30:00-04:00  63.779999  63.884998  63.619999  63.880001
# 2024-05-24 09:31:00-04:00  63.880001  64.040001  63.820000  64.025398
# 2024-05-24 09:32:00-04:00  64.040001  64.191399  64.040001  64.187103
# 2024-05-24 09:33:00-04:00  64.175003  64.300003  64.160004  64.220001
# 2024-05-24 09:34:00-04:00  64.199997  64.459999  64.190002  64.449997
# ...                              ...        ...        ...        ...
# 2024-05-31 09:44:00-04:00  64.169998  64.169998  64.010002  64.044998
# 2024-05-31 09:45:00-04:00  64.044998  64.119499  63.910000  63.919998
# 2024-05-31 09:46:00-04:00  63.910000  64.010002  63.889999  63.930000
# 2024-05-31 09:47:00-04:00  63.919998  63.936401  63.860001  63.930000
# 2024-05-31 09:48:00-04:00  63.939999  63.939999  63.939999  63.939999
#
#                            Adj Close  Volume
# ...

# %%
data = yf.download(tickers='UBER',period='5d',interval='1m')

fig = go.Figure()

fig.add_trace(go.Candlestick(x=data.index,
                                open=data['Open'],
                                high=data['High'],
                                low=data['Low'],
                                close=data['Close'],
                                name = 'Market data'))
fig.update_layout(
    title='uber',
    yaxis_title='usd'
)

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute",stepmode="backward"),
            dict(count=45, label="45m", step="minute",stepmode="backward"),
            dict(count=1, label="1HTD", step="hour",stepmode="todate"),
            dict(count=3, label="2h", step="hour",stepmode="backward"),
            dict(step="all")
        ])
    )
)

fig.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed
